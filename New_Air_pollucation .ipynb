# %%
import pandas as pd
import matplotlib.pyplot as plt


var = pd.read_csv("C:\\Users\\sahub\\OneDrive\\Desktop\\PandasPro\\Air Condiction.csv",encoding='utf-8')
var
# Out:
#                    city        city_ascii      lat       lng  \
# 0                 Tokyo             Tokyo  35.6870  139.7495
# 1               Jakarta           Jakarta  -6.1750  106.8275
# 2                 Delhi             Delhi  28.6100   77.2300
# 3             Guangzhou         Guangzhou  23.1300  113.2600
# 4                Mumbai            Mumbai  19.0761   72.8775
# ...                 ...               ...      ...       ...
# 48054          Al Jabīn          Al Jabin  14.7040   43.5990
# 48055         Nelspruit         Nelspruit -25.4745   30.9703
# 48056          Gqeberha          Gqeberha -33.9681   25.5981
# 48057            Lupane            Lupane -18.9315   27.8070
# 48058  Charlotte Amalie  Charlotte Amalie  18.3420  -64.9331
#
#                    country iso2 iso3          admin_name  capital  population  \
# 0                    Japan   JP  JPN               Tōkyō  primary  37785000.0
# ...

# %%
print(var.isnull().sum())
# Out:
# city          0
# city_ascii    0
# lat           0
# lng           0
# country       0
# iso2          0
# iso3          0
# admin_name    0
# capital       0
# population    0
# id            0
# dtype: int64

# %%
var.dropna()
# Out:
#                city    city_ascii      lat       lng          country iso2  \
# 0             Tokyo         Tokyo  35.6870  139.7495            Japan   JP
# 1           Jakarta       Jakarta  -6.1750  106.8275        Indonesia   ID
# 2             Delhi         Delhi  28.6100   77.2300            India   IN
# 3         Guangzhou     Guangzhou  23.1300  113.2600            China   CN
# 4            Mumbai        Mumbai  19.0761   72.8775            India   IN
# ...             ...           ...      ...       ...              ...  ...
# 47751       Samamea       Samamea -13.9333 -171.5333            Samoa   WS
# 47753     Bogovinje     Bogovinje  41.9233   20.9133  North Macedonia   MK
# 47758       Vransko       Vransko  46.1720   14.8217         Slovenia   SI
# 47768  Gaigirgordub  Gaigirgordub   9.5583  -78.9483           Panama   PA
# 47803        Kostel        Kostel  45.5088   14.9100         Slovenia   SI
#
#       iso3     admin_name  capital  population          id
# ...

# %%
var = pd.read_csv("C:\\Users\\sahub\\OneDrive\\Desktop\\PandasPro\\Air Condiction.csv",encoding='utf-8')

new_var = var.dropna()

print(new_var.to_string())
# Out:
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)

# %%
print(var.head())
# Out:
#         city city_ascii      lat       lng    country iso2 iso3   admin_name  \
# 0      Tokyo      Tokyo  35.6870  139.7495      Japan   JP  JPN        Tōkyō
# 1    Jakarta    Jakarta  -6.1750  106.8275  Indonesia   ID  IDN      Jakarta
# 2      Delhi      Delhi  28.6100   77.2300      India   IN  IND        Delhi
# 3  Guangzhou  Guangzhou  23.1300  113.2600      China   CN  CHN    Guangdong
# 4     Mumbai     Mumbai  19.0761   72.8775      India   IN  IND  Mahārāshtra
#
#    capital  population          id
# 0  primary  37785000.0  1392685764
# 1  primary  33756000.0  1360771077
# 2    admin  32226000.0  1356872604
# 3    admin  26940000.0  1156237133
# 4    admin  24973000.0  1356226629

# %%
top_districts = var.groupby('city')['lat'].mean().sort_values(ascending=False)
print(top_districts.head())
# Out:
# city
# Nord            81.7166
# Longyearbyen    78.2167
# Qaanaaq         77.4667
# Savissivik      76.0194
# Zemlya Bunge    74.8983
# Name: lat, dtype: float64

# %%
top_districts = var.groupby('city')['lng'].mean().sort_values(ascending=False)
print(top_districts.head())
# Out:
# city
# Labasa          179.3667
# Beringovskiy    179.3067
# Funafuti        179.2000
# Nausori         178.5454
# Nakasi          178.5214
# Name: lng, dtype: float64

# %%
top_districts = var.groupby('city')['population'].mean().sort_values(ascending=False)
print(top_districts.head())
# Out:
# city
# Tokyo        37785000.0
# Jakarta      33756000.0
# Guangzhou    26940000.0
# Mumbai       24973000.0
# Manila       24922000.0
# Name: population, dtype: float64

# %%
top_districts = var.groupby('city')['id'].mean().sort_values(ascending=False)
print(top_districts.head())
# Out:
# city
# Bayt Ūmmar    1.934976e+09
# Yattir        1.934947e+09
# Bayt Sāḩūr    1.934946e+09
# Ya‘bad        1.934943e+09
# Bayt Jālā     1.934811e+09
# Name: id, dtype: float64
